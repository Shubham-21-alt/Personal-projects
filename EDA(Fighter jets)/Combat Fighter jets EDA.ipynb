# %%
from IPython.display import Image

# %%
Image("C:\\Users\\DELL\\Pictures\\jets\\642190.jpg")

# %% [markdown]
# # Importing Libraries and Dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import  numpy as np
import pandas as pd

# %%
df=pd.read_csv("Fightjet.csv")

# %% [markdown]
# # Analysing Dataset

# %%
df.head()
# Out:
#   AircraftType    NameofJet              ManufacturerofJet  YearofManufacture  \
# 0      Fighter     Lockheed               Lockheed Martin                2005
# 1      Fighter       Sukhoi                         Sukhoi               2010
# 2      Fighter     Dassault              Dassault Aviation               2012
# 3      Fighter       Boeing                         Boeing               2008
# 4      Fighter  Eurofighter  Eurofighter Jagdflugzeug GmbH               2015
#
#    MaxSpeed  RangeinMiles  MaxAltitude                Weapons  CrewSize  Cost  \
# 0      1500          1200        50000         Missiles, Guns         1   100
# 1      1700          1300        55000         Missiles, Guns         1   110
# 2      1600          1400        60000  Missiles, Guns, Bombs         2   120
# 3      1550          1250        52000         Missiles, Guns         1    95
# 4      1800          1350        58000         Missiles, Guns         1   130
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AircraftType       32 non-null     object
#  1   NameofJet          32 non-null     object
#  2   ManufacturerofJet  32 non-null     object
#  3   YearofManufacture  32 non-null     int64
#  4   MaxSpeed           32 non-null     int64
#  5   RangeinMiles       32 non-null     int64
#  6   MaxAltitude        32 non-null     int64
#  7   Weapons            32 non-null     object
#  8   CrewSize           32 non-null     int64
#  9   Cost               32 non-null     int64
#  10  CountryofOrigin    32 non-null     object
#  11  EngineType         32 non-null     object
#  12  Length(ft)         32 non-null     float64
#  13  Wingspan           32 non-null     float64
#  14  CombatRange        32 non-null     object
#  15  ServiceCeiling     32 non-null     int64
# ...

# %%
df.isna().any()
# Out:
# AircraftType         False
# NameofJet            False
# ManufacturerofJet    False
# YearofManufacture    False
# MaxSpeed             False
# RangeinMiles         False
# MaxAltitude          False
# Weapons              False
# CrewSize             False
# Cost                 False
# CountryofOrigin      False
# EngineType           False
# Length(ft)           False
# Wingspan             False
# CombatRange          False
# ServiceCeiling       False
# Introduced           False
# RadarType            False
# RadarRange           False
# StealthTechnology    False
# EjectionSystem        True
# AvionicsSystem        True
# Armament             False
# MaximumGForce        False
# FuelCapacity         False
# BattlesWon           False
# FuelType             False
# Generation           False
# dtype: bool

# %%
df.dropna(axis = 0, inplace = True)

# %%
df.isna().any()
# Out:
# AircraftType         False
# NameofJet            False
# ManufacturerofJet    False
# YearofManufacture    False
# MaxSpeed             False
# RangeinMiles         False
# MaxAltitude          False
# Weapons              False
# CrewSize             False
# Cost                 False
# CountryofOrigin      False
# EngineType           False
# Length(ft)           False
# Wingspan             False
# CombatRange          False
# ServiceCeiling       False
# Introduced           False
# RadarType            False
# RadarRange           False
# StealthTechnology    False
# EjectionSystem       False
# AvionicsSystem       False
# Armament             False
# MaximumGForce        False
# FuelCapacity         False
# BattlesWon           False
# FuelType             False
# Generation           False
# dtype: bool

# %% [markdown]
# #  Jets produced by each Manufacturer

# %%
jet_comp=df["ManufacturerofJet"].value_counts()
jet_comp
# Out:
# Lockheed Martin                  3
# Dassault Aviation                3
# Chengdu                          3
# Mikoyan                          3
# Sukhoi                           3
# Saab                             2
# Northrop Grumman                 2
# North American Aviation          1
# Israel Aircraft Industries       1
# HAL                              1
# Mitsubishi                       1
# Vought                           1
# General Dynamics                 1
# Republic Aviation                1
# McDonnell Douglas                1
# Eurofighter Jagdflugzeug GmbH    1
# Boeing                           1
# Shenyang                         1
# Name: ManufacturerofJet, dtype: int64

# %%
plt.figure(figsize = (15,8))
jet_comp.plot(kind = "bar")
plt.show()

# %% [markdown]
# # Jets of Each Generation

# %%
jet_gen=df["Generation"].value_counts()
jet_gen
# Out:
# 4.0    12
# 4.5     6
# 5.0     4
# 2.0     4
# 3.0     3
# 1.0     1
# Name: Generation, dtype: int64

# %%
plt.figure(figsize = (15,8))
jet_gen.plot(kind = "barh",color='coral')
plt.show()

# %% [markdown]
# # Relationship Between Max speed,Max Altitude,Range

# %%
# Calculate correlation between Max Speed and Range in Miles
correlation_speed_range = df['MaxSpeed'].corr(df['RangeinMiles'])

# Calculate correlation between Max Altitude and Range in Miles
correlation_altitude_range = df['MaxAltitude'].corr(df['RangeinMiles'])

# Calculate correlation between Max Speed and Max Altitude
correlation_speed_altitude = df['MaxSpeed'].corr(df['MaxAltitude'])

# Create a scatterplot grid
plt.figure(figsize=(18, 6))

# Scatterplot for Max Speed vs Range in Miles
plt.subplot(1, 3, 1)
sns.scatterplot(x='MaxSpeed', y='RangeinMiles', data=df)
plt.title(f'Max Speed vs Range in Miles\nCorrelation: {correlation_speed_range:.2f}')
plt.xlabel('Max Speed')
plt.ylabel('Range in Miles')

# Scatterplot for Max Altitude vs Range in Miles
plt.subplot(1, 3, 2)
sns.scatterplot(x='MaxAltitude', y='RangeinMiles', data=df)
plt.title(f'Max Altitude vs Range in Miles\nCorrelation: {correlation_altitude_range:.2f}')
plt.xlabel('Max Altitude')
plt.ylabel('Range in Miles')

# Scatterplot for Max Speed vs Max Altitude
plt.subplot(1, 3, 3)
sns.scatterplot(x='MaxSpeed', y='MaxAltitude', data=df)
plt.title(f'Max Speed vs Max Altitude\nCorrelation: {correlation_speed_altitude:.2f}')
plt.xlabel('Max Speed')
plt.ylabel('Max Altitude')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Global Contribution to Jet Manufacturing

# %%
# Countplot for Country of Origin
plt.figure(figsize=(20,8))
sns.countplot(x='CountryofOrigin', data=df, order=df['CountryofOrigin'].value_counts().index)
plt.title('Distribution of Combat Fighter Jets by Country of Origin')
plt.xlabel('Country of Origin')
plt.ylabel('Number of Jets Manufactured')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# # Impact of Generation on Performance Metrics

# %%
# Create a boxplot layout for Max Speed, Range in Miles, and Max Altitude across Generations
plt.figure(figsize=(18, 6))

# Boxplot for Max Speed across Generations
plt.subplot(1, 3, 1)
sns.boxplot(x='Generation', y='MaxSpeed', data=df, order=df.groupby('Generation')['MaxSpeed'].median().sort_values(ascending=False).index)
plt.title('Max Speed Across Generations')
plt.xlabel('Generation')
plt.ylabel('Max Speed')
plt.xticks(rotation=45, ha='right')

# Boxplot for Range in Miles across Generations
plt.subplot(1, 3, 2)
sns.boxplot(x='Generation', y='RangeinMiles', data=df, order=df.groupby('Generation')['RangeinMiles'].median().sort_values(ascending=False).index)
plt.title('Range in Miles Across Generations')
plt.xlabel('Generation')
plt.ylabel('Range in Miles')
plt.xticks(rotation=45, ha='right')

# Boxplot for Max Altitude across Generations
plt.subplot(1, 3, 3)
sns.boxplot(x='Generation', y='MaxAltitude', data=df, order=df.groupby('Generation')['MaxAltitude'].median().sort_values(ascending=False).index)
plt.title('Max Altitude Across Generations')
plt.xlabel('Generation')
plt.ylabel('Max Altitude')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Trends in Engine Types

# %%
# Count the occurrences of each Engine Type
engine_type_counts = df['EngineType'].value_counts()

# Create a pie chart for Engine Types with percentage values
plt.figure(figsize=(5, 5))
plt.pie(engine_type_counts, labels=engine_type_counts.index, autopct=lambda p: '{:.1f}%'.format(p) if p > 0 else '', startangle=90, colors=sns.color_palette('Set3'))
plt.title('Distribution of Engine Types in Combat Fighter Jets')
plt.show()

# %% [markdown]
# # Cost of jets vs Type of Engines

# %%
plt.figure(figsize=(14, 8))
sns.violinplot(x='EngineType', y='Cost', data=df, order=df.groupby('EngineType')['Cost'].median().sort_values(ascending=False).index)
plt.title('Violin Plot of Price Across Engine Types')
plt.xlabel('Engine Type')
plt.ylabel('Cost')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #  Correlation Heatmap

# %%
# Extracting numerical columns for correlation matrix
numerical_columns = ['CombatRange', 'Length(ft)', 'FuelCapacity', 'CrewSize', 'Cost',"Generation","Wingspan"]

# Calculate correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Plotting the heatmap
plt.figure(figsize=(6,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14672\3432622483.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df[numerical_columns].corr()

# %% [markdown]
# # Stealth Technology vs Battles won

# %%
plt.figure(figsize=(6, 6))
sns.pointplot(x='StealthTechnology', y='BattlesWon', data=df, errorbar=None)
plt.title('Stealth Technology vs Battles Won')
plt.xlabel('Stealth Technology')
plt.ylabel('Number of Battles Won')
plt.show()
